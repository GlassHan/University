# %%
#계산기

from tkinter import *
from decimal import *

#메인
window=Tk()
window.title("cal")

#내용수정이 가능한 엔트리 위젯을 사용해 결과 디스플레이 사용
display=Entry(window, width=45, bg="light green")
display.grid()

#숫자 버튼
def click1():
    display.insert(END, "1")

Button(window, text="1", width=5, command=click1).grid(row=1,column=0)


#실행
window.mainloop()

# %%
#계산기

from tkinter import *
from decimal import *

#숫자 버튼
def click(key):
    display.insert(END, key)
    
#메인
window=Tk()
window.title("cal")

top_row=Frame(window)
top_row.grid(row=0,column=0,columnspan=2, sticky=N)

#내용수정이 가능한 엔트리 위젯을 사용해 결과 디스플레이 사용
display=Entry(top_row, width=45, bg="light green")
display.grid()

num_pad=Frame(window)
num_pad.grid(row=1,column=0, sticky=W)

num_pad_list=[
    '7','8','9',
    '4','5','6',
    '1','2','3',
    '0','.','='
]

r=0
c=0

for btn_text in num_pad_list:
    Button(num_pad, text=btn_text, width=5, command=click(btn_text)).grid(row=r,column=c)
    c=c+1
    if c>2:
        c=0
        r=r+1
        
        

plus_pad=Frame(window)
plus_pad.grid(row=1,column=1, sticky=E)

plus_pad_list=[
    '*','/',
    '+','-',
    '(',')',
    'C'
]

r=0
c=0

for btn_text1 in plus_pad_list:
    Button(plus_pad, text=btn_text1, width=5, command=click(btn_text1)).grid(row=r,column=c)
    c=c+1
    if c>1:
        c=0
        r=r+1
        


#실행
window.mainloop()
